# %%
import backtrader as bt
#import yfinance as yf
import pandas as pd
#import pyfolio as pf
import datetime
import math
# import the package after installation
from backtrader_plotly.plotter import BacktraderPlotly
from backtrader_plotly.scheme import PlotScheme
import plotly.io
import warnings
import backtrader.feeds as btfeeds
warnings.filterwarnings("ignore")

# %% [markdown]
# This trading strategy involves both long and short positions based on specific conditions. For long positions, the conditions include a cross rate below the 10th percentile of the past 10-day cross rates, 1 minus the cross rate being greater than a threshold of 0.05, and the closing price being above the 5-day moving average. On the other hand, for short positions, the conditions are a cross rate above the 90th percentile of the past 10-day cross rates, cross rate minus 1 being greater than 0.05, and the closing price being below the 5-day moving average. Exiting long and short positions is determined solely by the closing price relative to the 5-day moving average. This code is designed to perform a backtest of this strategy.

# %% [markdown]
# # BIAS Research

# %%
import pandas as pd
import os
import plotly.graph_objs as go
import numpy as np

def load_data(filename):
    data = pd.read_csv(filename, parse_dates=['datetime'])
    data.set_index('datetime', inplace=True)
    return data

def filter_trading_hours(data):
    data = data.between_time('9:00', '15:00')
    return data

def resample_data(data, frequency):
    resampled_data = data.resample(frequency).agg({'open':'last', 'high':'last', 'low':'last', 'close':'last',
                                                   'volume':'sum', 'turnover':'sum', 'open_interest':'sum'})
    resampled_data = resampled_data.dropna()
    return resampled_data

def calculate_moving_average(data, N, ma_type='simple'):
    if ma_type == 'simple':
        data['N_MA'] = data['close'].rolling(window=N).mean()
    elif ma_type == 'exponential':
        data['N_MA'] = data['close'].ewm(span=N).mean()
    return data

def calculate_bias(data):
    data['BIAS'] = data['close'] / data['N_MA']
    return data

def calculate_rolling_statistics(data, X):
    data['bias_max'] = data['BIAS'].rolling(window=X).max()
    data['bias_min'] = data['BIAS'].rolling(window=X).min()
    for quantile in [10, 30, 50, 70, 90]:
        data[f'bias_{quantile}pct'] = data['BIAS'].rolling(window=X).quantile(quantile/100)
    return data

def calculate_bias_high_low(data):
    data['BIAS_high'] = np.where(data['BIAS'] > data['bias_90pct'], -1, 0)
    data['BIAS_low'] = np.where(data['BIAS'] < data['bias_10pct'], 1, 0)
    return data

def calculate_future_returns(data, Y, Z):
    data['BIAS_high_fut_ret'] = data['close'].shift(-Y)/data['close']
    data['BIAS_low_fut_ret'] = - (data['close'].shift(-Z)/data['close'])
    data['BIAS_high_low_ret'] = data['BIAS_high_fut_ret'] + data['BIAS_low_fut_ret']
    return data

def visualize_close_MA_bias(data):
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=data.index, y=data['close'], mode='lines', name='close'))
    fig.add_trace(go.Scatter(x=data.index, y=data['N_MA'], mode='lines', name='N_MA'))
    fig.add_trace(go.Scatter(x=data[data['BIAS_high']==1].index, y=data[data['BIAS_high']==1]['close'],
                             mode='markers', marker_symbol='triangle-up', name='BIAS_high=1 (Buy)'))
    fig.add_trace(go.Scatter(x=data[data['BIAS_high']==-1].index, y=data[data['BIAS_high']==-1]['close'],
                             mode='markers', marker_symbol='triangle-down', name='BIAS_high=-1 (Sell)'))
    fig.add_trace(go.Scatter(x=data[data['BIAS_low']==1].index, y=data[data['BIAS_low']==1]['close'],
                             mode='markers', marker_symbol='circle', name='BIAS_low=1 (Buy)'))
    fig.add_trace(go.Scatter(x=data[data['BIAS_low']==-1].index, y=data[data['BIAS_low']==-1]['close'],
                             mode='markers', marker_symbol='circle-open', name='BIAS_low=-1 (Sell)'))
    fig.update_layout(xaxis=dict(type='category'))
    fig.show()

# Visualize data using Plotly
def visualize_data(data):
    for column in data.columns:
        if data[column].dtype != 'object': # Plot only numeric data
            fig = px.line(data, y=column)
            fig.show()

def main(filename, frequency, N, ma_type, X, Y, Z):
    data = load_data(filename)
    data = filter_trading_hours(data)
    data = resample_data(data, frequency)
    data = calculate_moving_average(data, N, ma_type)
    data = calculate_bias(data)
    data = calculate_rolling_statistics(data, X)
    data = calculate_bias_high_low(data)
    data = calculate_future_returns(data, Y, Z)
    visualize_close_MA_bias(data)
    # visualize_data(data)
    return data

if __name__ == "__main__":
    # data = main('ag2306.csv', '15T', 5, 'simple', 20, 5, 5)
    data = main('a2307.csv', '15T', 5, 'simple', 20, 5, 5)

# %% [markdown]
# The trading output provided demonstrates the performance of the Bias Strategy when it is applied to a specific dataset with 15-minute time intervals and a 10-period Moving Average window.
# The Bias Strategy operates according to a simple rule on the ground of the Moving Average (MA) of the asset's price.
# Moreover, it adopts a 10-period moving average, which means the strategy tends to calculate the average price of the asset over the last 10 periods (each period being 15 minutes in the case).
# Besides, the strategy generates a signal of buying if the Moving Average price is 10 units more than the current (spot) price, which indicates the price is expected to rise.
# Conversely, the strategy generates a signal of selling if the Moving Average price is 10 units less than the current price, demonstrating the price is expected to drop.

# %%
class BiasStrategy(bt.Strategy):
    params = (("para_ma", 20),
              ("bias_len",10),
              ("para_risk_ma", 5),
              ("high_q", 90),
              ("low_q", 10),
              ("bias_thresh", 0.05),

              )

    def __init__(self):
        self.close_len = 1000
        self.order_history = []
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # get all indicators
        self.close = self.datas[0].close
        self.ma = self.datas[0].ma
        self.risk_ma = self.datas[0].risk_ma
        self.bias = self.datas[0].bias
        self.bias_hi = self.datas[0].bias_hi
        self.bias_lo = self.datas[0].bias_lo


    def next(self):
        # if there's any pending orders that haven't been filled, then we don't move on to the next steps, other wise we do.
        # The logic is that new orders are not to be sent until old orders are either canceled or filled.
        # After filling orders, self.order will be set to be None
        if self.order:
            return

        if self.position.size > 0: # if there're long position
            if self.close[0] < self.risk_ma[0]: # and there's risk
                self.order = self.sell() # close long pos

        elif self.position.size < 0: # if there're short position
            if self.close[0] > self.risk_ma[0]: # and there's risk
                self.order = self.buy() # close short pos

        else: # if there're no positions
            if (self.bias[0] > self.bias_hi[0]) & (self.bias[0]-1 > self.params.bias_thresh) & (self.close[0] < self.risk_ma[0]): # if short signals are triggered
                self.order = self.sell() # enter short pos

            elif (self.bias[0] < self.bias_lo[0]) & (1-self.bias[0] > self.params.bias_thresh) & (self.close[0] > self.risk_ma[0]): # if long signals are triggered
                self.order = self.buy() # enter long pos


    # outputting information
    def log(self, txt):
        dt=self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status == order.Completed:
            self.order_history.append({'datetime': bt.num2date(order.executed.dt),  # 订单执行的日期和时间
                            'price': order.executed.price,  # 订单执行的价格
                            'commission': order.executed.comm,  # 佣金
                            'value': order.executed.value,  # 订单价值
                            'size': order.executed.size,  # 订单规模（购买/卖出的股票数量）
                            'type': 'buy' if order.isbuy() else 'sell',  # 订单类型
                            'ref': order.ref  # 订单的引用号
                            })
            # if order.isbuy():
            #     self.log(
            # 	"Executed BUY (Price: %.2f, Value: %.2f, Commission %.2f)" %
            # 	(order.executed.price, order.executed.value, order.executed.comm))
            # else:
            #     self.log(
            # 	"Executed SELL (Price: %.2f, Value: %.2f, Commission %.2f)" %
            # 	(order.executed.price, order.executed.value, order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log("Order was canceled/margin/rejected")
        self.order = None

    def stop(self):
        ending_value = self.broker.getvalue()
        self.log(f"para_ma:{self.params.para_ma}, \
                 bias_len:{self.params.bias_len}, \
                 para_risk_ma:{self.params.para_risk_ma}, \
                 high_q:{self.params.high_q},\
                 low_q:{self.params.low_q},\
                 bias_thresh:{self.params.bias_thresh},\
                 ending value: {ending_value}")

# %%
# Choose one of the backtesting processes, either single backtesting or performance optimization

if __name__ == '__main__':
    # parameters
    para_ma = 20
    bias_len = 10
    para_risk_ma = 5
    high_q = 90
    low_q = 10

    # read csv data
    filename = 'a2307.csv'
    data = pd.read_csv(filename)
    # calulate all indicators
    data['ma'] = data['close'].rolling(window=para_ma).mean()
    data['risk_ma'] = data['close'].rolling(window=para_risk_ma).mean()
    data['bias'] = data['close'] / data['ma']
    data['bias_hi'] = data['bias'].rolling(window=bias_len).quantile(high_q/100)
    data['bias_lo'] = data['bias'].rolling(window=bias_len).quantile(low_q/100)
    data['datetime'] = pd.to_datetime(data['datetime'], format='%Y/%m/%d %H:%M')

    # import all data
    class NewData(bt.feeds.PandasData):
        lines = ('ma', 'risk_ma', 'bias', 'bias_hi', 'bias_lo')
        params = (('ma', 9), ('risk_ma', 10), ('bias', 11), ('bias_hi', 12), ('bias_lo', 13))
    data = NewData(
        dataname=data,
        datetime=2,
        open=3,
        high=4,
        low=5,
        close=6,
        volume=7,
        openinterest=8,
        ma=9,
        risk_ma = 10,
        bias=11,
        bias_hi=12,
        bias_lo=13,
        fromdate=datetime.datetime(2023, 5, 18),
        todate=datetime.datetime(2023, 6, 8)
    )

    optimize = False
    if optimize == False:
        print("Single Backtest..")
        # %matplotlib inline
        # Create a cerebro instance, add our strategy, some starting cash at broker and a 0.1% broker commission
        cerebro = bt.Cerebro()
        cerebro.addstrategy(BiasStrategy)
        cerebro.broker.setcash(1000000)
        cerebro.broker.setcommission(commission=0.0000)
        cerebro.broker.set_slippage_perc(0.0000)
        # data = bt.feeds.PandasData(dataname=yf.download("SPY", "2015-1-2", "2023-1-30"))

        # cerebro.resampledata(data, timeframe=bt.TimeFrame.Minutes, compression=15)
        cerebro.adddata(data) #if using resample, then comment this line of code
        # cerebro.addsizer(bt.sizers.PercentSizer, percents=80)
        cerebro.addsizer(bt.sizers.SizerFix, stake=1)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name = 'SharpeRatio', timeframe=bt.TimeFrame.Minutes, riskfreerate=0.01)
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name='DD')
        cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name="ta")



        print("========================")
        print(f'<START> Brokerage account: ${round(cerebro.broker.getvalue(),2)}')
        results = cerebro.run()
        strat = results[0]
        trades = strat.analyzers.ta.get_analysis()
        freq_convertion = 252*7.5*4

        # Print the results
        print(f'<FINISH> Brokerage account: ${round(cerebro.broker.getvalue(),2)}')
        print(strat.params.para_ma, strat.params.bias_len, strat.params.para_risk_ma, strat.params.high_q,strat.params.low_q,strat.params.bias_thresh)
        # print('Sharpe Ratio:', strat.analyzers.SharpeRatio.get_analysis()['sharperatio']/math.sqrt(freq_convertion))
        # print('Max Drawdown %:', round(float(strat.analyzers.DD.get_analysis()['drawdown'])*100, 2))
        # print('Max Drawdown $ or RMB:', round(float(strat.analyzers.DD.get_analysis()['moneydown']), 2))


        # define plot scheme with new additional scheme arguments
        scheme = PlotScheme(decimal_places=2, max_legend_text_width=25)
        figs = cerebro.plot(BacktraderPlotly(show=False, scheme=scheme))

        # directly manipulate object using methods provided by `plotly`
        for i, each_run in enumerate(figs):
            each_run[i].update_layout(xaxis=dict(type='category'))
            for j, each_strategy_fig in enumerate(each_run):
                each_strategy_fig.update_layout(xaxis=dict(type='category'))
                each_strategy_fig.show()
                # open plot in browser
                # save the html of the plot to a variable
                html = plotly.io.to_html(each_strategy_fig, full_html=False)
                # write html to disk
                plotly.io.write_html(each_strategy_fig, f'{i}_{j}.html', full_html=True)



        # # use Pyfolio to show all the results:
        # cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
        # results = cerebro.run()
        # strat = results[0]
        # pyfoliozer = strat.analyzers.getbyname('pyfolio')

        # # %matplotlib inline
        # returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
        # print(f'The return of the strategy is: {returns}')
        # pf.create_full_tear_sheet(returns)
        # # Eventually solved the following issue by trying: pip install git+https://github.com/quantopian/pyfolio:
        # # AttributeError: 'numpy.int64' object has no attribute 'to_pydatetime'

    else:
        print("Start Optimizing..")
        cerebro = bt.Cerebro()
        cerebro.optstrategy(BiasStrategy)
        cerebro.broker.setcash(1000000)
        cerebro.broker.setcommission(commission=0.0003)
        cerebro.broker.set_slippage_perc(0.0001)

        cerebro.resampledata(data, timeframe=bt.TimeFrame.Minutes, compression=15)
        # cerebro.adddata(data) #if using resample, then comment this line of code
        # cerebro.addsizer(bt.sizers.PercentSizer, percents=80)
        cerebro.addsizer(bt.sizers.SizerFix, stake=1)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name = 'SharpeRatio', timeframe=bt.TimeFrame.Minutes, riskfreerate=0.01)
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name='DD')
        print("========================")
        print(f'<START> Brokerage account: ${round(cerebro.broker.getvalue(),2)}')
        results = cerebro.run(maxcpus=1)

        # Print the results
        print("========================")
        for res in results:
            res_ = res[0]
            print("--------------------------")
            print('Parameters:')
            print(res_.params.fast, res_.params.slow, res_.params.rumi)
            print('Sharpe Ratio:', res_.analyzers.SharpeRatio.get_analysis())
            print('Drawdown:', res_.analyzers.DD.get_analysis())

        # Find the result with the highest Sharpe Ratio
        print("========================")
        best_result = None
        best_sharpe = None
        best_dd = None

        for res in results:
            # based on drawdown
            dd = res[0].analyzers.DD.get_analysis()['drawdown']
            if best_dd is None or dd < best_dd:
                best_dd = dd
                best_result = res

            # # based on sharpe
            # sharpe = res[0].analyzers.SharpeRatio.get_analysis()['sharperatio']
            # if best_sharpe is None or sharpe > best_sharpe:
            # 	best_sharpe = sharpe
            # 	best_result = res
        # Print the best result
        print('Best Parameters:', best_result[0].params.fast, best_result[0].params.slow, best_result[0].params.rumi)
        # print('Best Sharpe:', best_sharpe)
        print('Best Drawdown:', best_result[0].analyzers.DD.get_analysis())
# Out:
# Single Backtest..
# ========================
# <START> Brokerage account: $1000000
# 2023-06-01, para_ma:20,                  bias_len:10,                  para_risk_ma:5,                  high_q:90,                 low_q:10,                 bias_thresh:0.05,                 ending value: 999992.0
# <FINISH> Brokerage account: $999992.0
# 20 10 5 90 10 0.05

# %% [markdown]
# ## Order History

# %%
for order in strat.order_history:
    print(order)
# Out:
# {'datetime': datetime.datetime(2023, 5, 18, 9, 33), 'price': 5056.4943, 'commission': 1.51694829, 'value': -5056.4943, 'size': -1, 'type': 'sell', 'ref': 1}
# {'datetime': datetime.datetime(2023, 5, 18, 9, 52), 'price': 5049.5049, 'commission': 1.5148514699999998, 'value': -5056.4943, 'size': 1, 'type': 'buy', 'ref': 2}
# {'datetime': datetime.datetime(2023, 5, 18, 9, 54), 'price': 5046.4953000000005, 'commission': 1.51394859, 'value': -5046.4953000000005, 'size': -1, 'type': 'sell', 'ref': 3}
# {'datetime': datetime.datetime(2023, 5, 18, 9, 55), 'price': 5048.0, 'commission': 1.5144, 'value': -5046.4953000000005, 'size': 1, 'type': 'buy', 'ref': 4}
# {'datetime': datetime.datetime(2023, 5, 18, 10, 4), 'price': 5047.4952, 'commission': 1.51424856, 'value': -5047.4952, 'size': -1, 'type': 'sell', 'ref': 5}
# {'datetime': datetime.datetime(2023, 5, 18, 10, 5), 'price': 5049.0, 'commission': 1.5147, 'value': -5047.4952, 'size': 1, 'type': 'buy', 'ref': 6}
# {'datetime': datetime.datetime(2023, 5, 18, 10, 6), 'price': 5048.4951, 'commission': 1.51454853, 'value': -5048.4951, 'size': -1, 'type': 'sell', 'ref': 7}
# {'datetime': datetime.datetime(2023, 5, 18, 10, 10), 'price': 5050.505, 'commission': 1.5151515, 'value': -5048.4951, 'size': 1, 'type': 'buy', 'ref': 8}
# {'datetime': datetime.datetime(2023, 5, 18, 10, 48), 'price': 5067.4932, 'commission': 1.5202479599999998, 'value': -5067.4932, 'size': -1, 'type': 'sell', 'ref': 9}
# {'datetime': datetime.datetime(2023, 5, 18, 10, 53), 'price': 5071.0, 'commission': 1.5212999999999999, 'value': -5067.4932, 'size': 1, 'type': 'buy', 'ref': 10}
# {'datetime': datetime.datetime(2023, 5, 18, 10, 59), 'price': 5069.493, 'commission': 1.5208479, 'value': -5069.493, 'size': -1, 'type': 'sell', 'ref': 11}
# {'datetime': datetime.datetime(2023, 5, 18, 11, 0), 'price': 5072.5072, 'commission': 1.52175216, 'value': -5069.493, 'size': 1, 'type': 'buy', 'ref': 12}
# {'datetime': datetime.datetime(2023, 5, 18, 11, 16), 'price': 5074.4925, 'commission': 1.52234775, 'value': -5074.4925, 'size': -1, 'type': 'sell', 'ref': 13}
# {'datetime': datetime.datetime(2023, 5, 18, 11, 20), 'price': 5076.5076, 'commission': 1.52295228, 'value': -5074.4925, 'size': 1, 'type': 'buy', 'ref': 14}
# {'datetime': datetime.datetime(2023, 5, 18, 11, 23), 'price': 5075.0, 'commission': 1.5225, 'value': -5075.0, 'size': -1, 'type': 'sell', 'ref': 15}
# {'datetime': datetime.datetime(2023, 5, 18, 11, 24), 'price': 5076.5076, 'commission': 1.52295228, 'value': -5075.0, 'size': 1, 'type': 'buy', 'ref': 16}
# {'datetime': datetime.datetime(2023, 5, 18, 11, 27), 'price': 5075.0, 'commission': 1.5225, 'value': -5075.0, 'size': -1, 'type': 'sell', 'ref': 17}
# {'datetime': datetime.datetime(2023, 5, 18, 11, 28), 'price': 5076.5076, 'commission': 1.52295228, 'value': -5075.0, 'size': 1, 'type': 'buy', 'ref': 18}
# {'datetime': datetime.datetime(2023, 5, 18, 13, 29), 'price': 5071.4928, 'commission': 1.5214478399999998, 'value': -5071.4928, 'size': -1, 'type': 'sell', 'ref': 19}
# {'datetime': datetime.datetime(2023, 5, 18, 13, 31), 'price': 5077.5077, 'commission': 1.52325231, 'value': -5071.4928, 'size': 1, 'type': 'buy', 'ref': 20}
# {'datetime': datetime.datetime(2023, 5, 18, 13, 34), 'price': 5074.4925, 'commission': 1.52234775, 'value': -5074.4925, 'size': -1, 'type': 'sell', 'ref': 21}
# {'datetime': datetime.datetime(2023, 5, 18, 13, 36), 'price': 5079.5079, 'commission': 1.5238523699999997, 'value': -5074.4925, 'size': 1, 'type': 'buy', 'ref': 22}
# {'datetime': datetime.datetime(2023, 5, 18, 13, 44), 'price': 5076.4923, 'commission': 1.5229476899999999, 'value': -5076.4923, 'size': -1, 'type': 'sell', 'ref': 23}
# {'datetime': datetime.datetime(2023, 5, 18, 13, 58), 'price': 5072.0, 'commission': 1.5215999999999998, 'value': -5076.4923, 'size': 1, 'type': 'buy', 'ref': 24}
# {'datetime': datetime.datetime(2023, 5, 18, 13, 59), 'price': 5074.0, 'commission': 1.5221999999999998, 'value': -5074.0, 'size': -1, 'type': 'sell', 'ref': 25}
# {'datetime': datetime.datetime(2023, 5, 18, 14, 0), 'price': 5074.0, 'commission': 1.5221999999999998, 'value': -5074.0, 'size': 1, 'type': 'buy', 'ref': 26}
# {'datetime': datetime.datetime(2023, 5, 18, 14, 2), 'price': 5070.0, 'commission': 1.521, 'value': -5070.0, 'size': -1, 'type': 'sell', 'ref': 27}
# {'datetime': datetime.datetime(2023, 5, 18, 14, 5), 'price': 5074.0, 'commission': 1.5221999999999998, 'value': -5070.0, 'size': 1, 'type': 'buy', 'ref': 28}
# {'datetime': datetime.datetime(2023, 5, 18, 14, 32), 'price': 5074.4925, 'commission': 1.52234775, 'value': -5074.4925, 'size': -1, 'type': 'sell', 'ref': 29}
# {'datetime': datetime.datetime(2023, 5, 18, 21, 0), 'price': 5073.5073, 'commission': 1.52205219, 'value': -5074.4925, 'size': 1, 'type': 'buy', 'ref': 30}
# {'datetime': datetime.datetime(2023, 5, 18, 21, 18), 'price': 5082.4917000000005, 'commission': 1.52474751, 'value': -5082.4917000000005, 'size': -1, 'type': 'sell', 'ref': 31}
# {'datetime': datetime.datetime(2023, 5, 18, 21, 34), 'price': 5075.5075, 'commission': 1.5226522499999997, 'value': -5082.4917000000005, 'size': 1, 'type': 'buy', 'ref': 32}
# {'datetime': datetime.datetime(2023, 5, 18, 21, 53), 'price': 5084.0, 'commission': 1.5252, 'value': -5084.0, 'size': -1, 'type': 'sell', 'ref': 33}
# {'datetime': datetime.datetime(2023, 5, 18, 21, 54), 'price': 5087.5087, 'commission': 1.52625261, 'value': -5084.0, 'size': 1, 'type': 'buy', 'ref': 34}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 11), 'price': 5089.0, 'commission': 1.5267, 'value': -5089.0, 'size': -1, 'type': 'sell', 'ref': 35}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 12), 'price': 5092.5091999999995, 'commission': 1.5277527599999998, 'value': -5089.0, 'size': 1, 'type': 'buy', 'ref': 36}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 21), 'price': 5090.4909, 'commission': 1.5271472699999997, 'value': -5090.4909, 'size': -1, 'type': 'sell', 'ref': 37}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 39), 'price': 5089.0, 'commission': 1.5267, 'value': -5090.4909, 'size': 1, 'type': 'buy', 'ref': 38}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 40), 'price': 5086.4913, 'commission': 1.5259473899999998, 'value': -5086.4913, 'size': -1, 'type': 'sell', 'ref': 39}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 41), 'price': 5088.0, 'commission': 1.5263999999999998, 'value': -5086.4913, 'size': 1, 'type': 'buy', 'ref': 40}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 43), 'price': 5084.4915, 'commission': 1.52534745, 'value': -5084.4915, 'size': -1, 'type': 'sell', 'ref': 41}
# {'datetime': datetime.datetime(2023, 5, 18, 22, 46), 'price': 5087.5087, 'commission': 1.52625261, 'value': -5084.4915, 'size': 1, 'type': 'buy', 'ref': 42}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 0), 'price': 5078.0, 'commission': 1.5233999999999999, 'value': -5078.0, 'size': -1, 'type': 'sell', 'ref': 43}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 2), 'price': 5093.5093, 'commission': 1.5280527899999998, 'value': -5078.0, 'size': 1, 'type': 'buy', 'ref': 44}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 4), 'price': 5088.4911, 'commission': 1.5265473299999999, 'value': -5088.4911, 'size': -1, 'type': 'sell', 'ref': 45}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 5), 'price': 5094.5094, 'commission': 1.5283528199999998, 'value': -5088.4911, 'size': 1, 'type': 'buy', 'ref': 46}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 8), 'price': 5085.0, 'commission': 1.5254999999999999, 'value': -5085.0, 'size': -1, 'type': 'sell', 'ref': 47}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 27), 'price': 5076.5076, 'commission': 1.52295228, 'value': -5085.0, 'size': 1, 'type': 'buy', 'ref': 48}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 48), 'price': 5087.0, 'commission': 1.5260999999999998, 'value': -5087.0, 'size': -1, 'type': 'sell', 'ref': 49}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 49), 'price': 5089.0, 'commission': 1.5267, 'value': -5087.0, 'size': 1, 'type': 'buy', 'ref': 50}
# {'datetime': datetime.datetime(2023, 5, 19, 9, 51), 'price': 5081.4918, 'commission': 1.5244475399999997, 'value': -5081.4918, 'size': -1, 'type': 'sell', 'ref': 51}
# {'datetime': datetime.datetime(2023, 5, 19, 10, 8), 'price': 5081.5081, 'commission': 1.52445243, 'value': -5081.4918, 'size': 1, 'type': 'buy', 'ref': 52}
# {'datetime': datetime.datetime(2023, 5, 19, 10, 9), 'price': 5080.0, 'commission': 1.5239999999999998, 'value': -5080.0, 'size': -1, 'type': 'sell', 'ref': 53}
# {'datetime': datetime.datetime(2023, 5, 19, 10, 10), 'price': 5084.0, 'commission': 1.5252, 'value': -5080.0, 'size': 1, 'type': 'buy', 'ref': 54}
# {'datetime': datetime.datetime(2023, 5, 19, 10, 54), 'price': 5097.4902, 'commission': 1.5292470599999999, 'value': -5097.4902, 'size': -1, 'type': 'sell', 'ref': 55}
# {'datetime': datetime.datetime(2023, 5, 19, 10, 55), 'price': 5100.51, 'commission': 1.5301529999999999, 'value': -5097.4902, 'size': 1, 'type': 'buy', 'ref': 56}
# {'datetime': datetime.datetime(2023, 5, 19, 10, 56), 'price': 5090.4909, 'commission': 1.5271472699999997, 'value': -5090.4909, 'size': -1, 'type': 'sell', 'ref': 57}
# {'datetime': datetime.datetime(2023, 5, 19, 11, 16), 'price': 5052.5052, 'commission': 1.5157515599999998, 'value': -5090.4909, 'size': 1, 'type': 'buy', 'ref': 58}
# {'datetime': datetime.datetime(2023, 5, 19, 13, 46), 'price': 5069.0, 'commission': 1.5207, 'value': -5069.0, 'size': -1, 'type': 'sell', 'ref': 59}
# {'datetime': datetime.datetime(2023, 5, 19, 13, 47), 'price': 5070.0, 'commission': 1.521, 'value': -5069.0, 'size': 1, 'type': 'buy', 'ref': 60}
# {'datetime': datetime.datetime(2023, 5, 19, 13, 48), 'price': 5064.4935000000005, 'commission': 1.51934805, 'value': -5064.4935000000005, 'size': -1, 'type': 'sell', 'ref': 61}
# {'datetime': datetime.datetime(2023, 5, 19, 13, 51), 'price': 5071.5071, 'commission': 1.52145213, 'value': -5064.4935000000005, 'size': 1, 'type': 'buy', 'ref': 62}
# {'datetime': datetime.datetime(2023, 5, 19, 13, 55), 'price': 5070.0, 'commission': 1.521, 'value': -5070.0, 'size': -1, 'type': 'sell', 'ref': 63}
# {'datetime': datetime.datetime(2023, 5, 19, 13, 56), 'price': 5071.5071, 'commission': 1.52145213, 'value': -5070.0, 'size': 1, 'type': 'buy', 'ref': 64}
# {'datetime': datetime.datetime(2023, 5, 19, 13, 58), 'price': 5071.4928, 'commission': 1.5214478399999998, 'value': -5071.4928, 'size': -1, 'type': 'sell', 'ref': 65}
# {'datetime': datetime.datetime(2023, 5, 19, 14, 2), 'price': 5072.5072, 'commission': 1.52175216, 'value': -5071.4928, 'size': 1, 'type': 'buy', 'ref': 66}
# {'datetime': datetime.datetime(2023, 5, 19, 14, 6), 'price': 5070.4929, 'commission': 1.5211478699999998, 'value': -5070.4929, 'size': -1, 'type': 'sell', 'ref': 67}
# {'datetime': datetime.datetime(2023, 5, 19, 14, 52), 'price': 5053.5053, 'commission': 1.5160515899999998, 'value': -5070.4929, 'size': 1, 'type': 'buy', 'ref': 68}
# {'datetime': datetime.datetime(2023, 5, 19, 14, 53), 'price': 5047.4952, 'commission': 1.51424856, 'value': -5047.4952, 'size': -1, 'type': 'sell', 'ref': 69}
# {'datetime': datetime.datetime(2023, 5, 19, 14, 58), 'price': 5052.5052, 'commission': 1.5157515599999998, 'value': -5047.4952, 'size': 1, 'type': 'buy', 'ref': 70}
# {'datetime': datetime.datetime(2023, 5, 19, 21, 5), 'price': 5050.0, 'commission': 1.515, 'value': -5050.0, 'size': -1, 'type': 'sell', 'ref': 71}
# {'datetime': datetime.datetime(2023, 5, 19, 21, 6), 'price': 5053.5053, 'commission': 1.5160515899999998, 'value': -5050.0, 'size': 1, 'type': 'buy', 'ref': 72}
# {'datetime': datetime.datetime(2023, 5, 19, 21, 7), 'price': 5045.4954, 'commission': 1.51364862, 'value': -5045.4954, 'size': -1, 'type': 'sell', 'ref': 73}
# {'datetime': datetime.datetime(2023, 5, 19, 21, 20), 'price': 5051.5051, 'commission': 1.51545153, 'value': -5045.4954, 'size': 1, 'type': 'buy', 'ref': 74}
# {'datetime': datetime.datetime(2023, 5, 19, 21, 28), 'price': 5044.4955, 'commission': 1.51334865, 'value': -5044.4955, 'size': -1, 'type': 'sell', 'ref': 75}
# {'datetime': datetime.datetime(2023, 5, 19, 21, 39), 'price': 5047.5046999999995, 'commission': 1.5142514099999997, 'value': -5044.4955, 'size': 1, 'type': 'buy', 'ref': 76}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 8), 'price': 5059.494, 'commission': 1.5178481999999998, 'value': -5059.494, 'size': -1, 'type': 'sell', 'ref': 77}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 9), 'price': 5060.506, 'commission': 1.5181518, 'value': -5059.494, 'size': 1, 'type': 'buy', 'ref': 78}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 10), 'price': 5057.4942, 'commission': 1.51724826, 'value': -5057.4942, 'size': -1, 'type': 'sell', 'ref': 79}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 19), 'price': 5060.506, 'commission': 1.5181518, 'value': -5057.4942, 'size': 1, 'type': 'buy', 'ref': 80}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 35), 'price': 5063.4936, 'commission': 1.51904808, 'value': -5063.4936, 'size': -1, 'type': 'sell', 'ref': 81}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 37), 'price': 5068.5068, 'commission': 1.5205520399999999, 'value': -5063.4936, 'size': 1, 'type': 'buy', 'ref': 82}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 47), 'price': 5068.4931, 'commission': 1.5205479299999998, 'value': -5068.4931, 'size': -1, 'type': 'sell', 'ref': 83}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 53), 'price': 5070.507, 'commission': 1.5211520999999997, 'value': -5068.4931, 'size': 1, 'type': 'buy', 'ref': 84}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 56), 'price': 5069.0, 'commission': 1.5207, 'value': -5069.0, 'size': -1, 'type': 'sell', 'ref': 85}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 57), 'price': 5071.5071, 'commission': 1.52145213, 'value': -5069.0, 'size': 1, 'type': 'buy', 'ref': 86}
# {'datetime': datetime.datetime(2023, 5, 19, 22, 58), 'price': 5069.0, 'commission': 1.5207, 'value': -5069.0, 'size': -1, 'type': 'sell', 'ref': 87}
# {'datetime': datetime.datetime(2023, 5, 22, 22, 59), 'price': 5070.507, 'commission': 1.5211520999999997, 'value': -5069.0, 'size': 1, 'type': 'buy', 'ref': 88}
# {'datetime': datetime.datetime(2023, 5, 23, 7, 33), 'price': 5031.0, 'commission': 1.5092999999999999, 'value': -5031.0, 'size': -1, 'type': 'sell', 'ref': 89}
# {'datetime': datetime.datetime(2023, 5, 23, 9, 11), 'price': 5047.5046999999995, 'commission': 1.5142514099999997, 'value': -5031.0, 'size': 1, 'type': 'buy', 'ref': 90}
# {'datetime': datetime.datetime(2023, 5, 23, 9, 33), 'price': 5055.4944000000005, 'commission': 1.51664832, 'value': -5055.4944000000005, 'size': -1, 'type': 'sell', 'ref': 91}
# {'datetime': datetime.datetime(2023, 5, 23, 10, 2), 'price': 5044.5044, 'commission': 1.5133513199999997, 'value': -5055.4944000000005, 'size': 1, 'type': 'buy', 'ref': 92}
# {'datetime': datetime.datetime(2023, 5, 23, 10, 49), 'price': 5055.4944000000005, 'commission': 1.51664832, 'value': -5055.4944000000005, 'size': -1, 'type': 'sell', 'ref': 93}
# {'datetime': datetime.datetime(2023, 5, 23, 10, 58), 'price': 5059.0, 'commission': 1.5176999999999998, 'value': -5055.4944000000005, 'size': 1, 'type': 'buy', 'ref': 94}
# {'datetime': datetime.datetime(2023, 5, 23, 10, 59), 'price': 5057.4942, 'commission': 1.51724826, 'value': -5057.4942, 'size': -1, 'type': 'sell', 'ref': 95}
# {'datetime': datetime.datetime(2023, 5, 23, 11, 24), 'price': 5048.0, 'commission': 1.5144, 'value': -5057.4942, 'size': 1, 'type': 'buy', 'ref': 96}
# {'datetime': datetime.datetime(2023, 5, 23, 11, 25), 'price': 5045.0, 'commission': 1.5134999999999998, 'value': -5045.0, 'size': -1, 'type': 'sell', 'ref': 97}
# {'datetime': datetime.datetime(2023, 5, 23, 11, 29), 'price': 5047.0, 'commission': 1.5140999999999998, 'value': -5045.0, 'size': 1, 'type': 'buy', 'ref': 98}
# {'datetime': datetime.datetime(2023, 5, 23, 13, 29), 'price': 5044.0, 'commission': 1.5131999999999999, 'value': -5044.0, 'size': -1, 'type': 'sell', 'ref': 99}
# {'datetime': datetime.datetime(2023, 5, 23, 13, 32), 'price': 5053.5053, 'commission': 1.5160515899999998, 'value': -5044.0, 'size': 1, 'type': 'buy', 'ref': 100}
# {'datetime': datetime.datetime(2023, 5, 23, 13, 44), 'price': 5048.4951, 'commission': 1.51454853, 'value': -5048.4951, 'size': -1, 'type': 'sell', 'ref': 101}
# {'datetime': datetime.datetime(2023, 5, 23, 13, 46), 'price': 5051.5051, 'commission': 1.51545153, 'value': -5048.4951, 'size': 1, 'type': 'buy', 'ref': 102}
# {'datetime': datetime.datetime(2023, 5, 23, 13, 51), 'price': 5052.0, 'commission': 1.5155999999999998, 'value': -5052.0, 'size': -1, 'type': 'sell', 'ref': 103}
# {'datetime': datetime.datetime(2023, 5, 23, 13, 52), 'price': 5056.5055999999995, 'commission': 1.5169516799999998, 'value': -5052.0, 'size': 1, 'type': 'buy', 'ref': 104}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 13), 'price': 5060.0, 'commission': 1.5179999999999998, 'value': -5060.0, 'size': -1, 'type': 'sell', 'ref': 105}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 15), 'price': 5064.0, 'commission': 1.5191999999999999, 'value': -5060.0, 'size': 1, 'type': 'buy', 'ref': 106}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 16), 'price': 5062.0, 'commission': 1.5186, 'value': -5062.0, 'size': -1, 'type': 'sell', 'ref': 107}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 17), 'price': 5064.0, 'commission': 1.5191999999999999, 'value': -5062.0, 'size': 1, 'type': 'buy', 'ref': 108}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 19), 'price': 5063.0, 'commission': 1.5189, 'value': -5063.0, 'size': -1, 'type': 'sell', 'ref': 109}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 20), 'price': 5064.5064, 'commission': 1.5193519199999999, 'value': -5063.0, 'size': 1, 'type': 'buy', 'ref': 110}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 23), 'price': 5061.4938, 'commission': 1.5184481399999998, 'value': -5061.4938, 'size': -1, 'type': 'sell', 'ref': 111}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 37), 'price': 5063.5063, 'commission': 1.5190518899999998, 'value': -5061.4938, 'size': 1, 'type': 'buy', 'ref': 112}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 48), 'price': 5060.4939, 'commission': 1.51814817, 'value': -5060.4939, 'size': -1, 'type': 'sell', 'ref': 113}
# {'datetime': datetime.datetime(2023, 5, 23, 14, 53), 'price': 5066.0, 'commission': 1.5197999999999998, 'value': -5060.4939, 'size': 1, 'type': 'buy', 'ref': 114}
# {'datetime': datetime.datetime(2023, 5, 23, 21, 0), 'price': 5064.4935000000005, 'commission': 1.51934805, 'value': -5064.4935000000005, 'size': -1, 'type': 'sell', 'ref': 115}
# {'datetime': datetime.datetime(2023, 5, 23, 21, 1), 'price': 5064.5064, 'commission': 1.5193519199999999, 'value': -5064.4935000000005, 'size': 1, 'type': 'buy', 'ref': 116}
# {'datetime': datetime.datetime(2023, 5, 23, 21, 2), 'price': 5055.4944000000005, 'commission': 1.51664832, 'value': -5055.4944000000005, 'size': -1, 'type': 'sell', 'ref': 117}
# {'datetime': datetime.datetime(2023, 5, 23, 21, 16), 'price': 5056.5055999999995, 'commission': 1.5169516799999998, 'value': -5055.4944000000005, 'size': 1, 'type': 'buy', 'ref': 118}
# {'datetime': datetime.datetime(2023, 5, 23, 21, 34), 'price': 5060.4939, 'commission': 1.51814817, 'value': -5060.4939, 'size': -1, 'type': 'sell', 'ref': 119}
# {'datetime': datetime.datetime(2023, 5, 23, 21, 38), 'price': 5066.0, 'commission': 1.5197999999999998, 'value': -5060.4939, 'size': 1, 'type': 'buy', 'ref': 120}
# {'datetime': datetime.datetime(2023, 5, 23, 21, 41), 'price': 5063.4936, 'commission': 1.51904808, 'value': -5063.4936, 'size': -1, 'type': 'sell', 'ref': 121}
# {'datetime': datetime.datetime(2023, 5, 23, 22, 1), 'price': 5057.0, 'commission': 1.5171, 'value': -5063.4936, 'size': 1, 'type': 'buy', 'ref': 122}
# {'datetime': datetime.datetime(2023, 5, 23, 22, 2), 'price': 5054.0, 'commission': 1.5161999999999998, 'value': -5054.0, 'size': -1, 'type': 'sell', 'ref': 123}
# {'datetime': datetime.datetime(2023, 5, 23, 22, 3), 'price': 5056.0, 'commission': 1.5168, 'value': -5054.0, 'size': 1, 'type': 'buy', 'ref': 124}
# {'datetime': datetime.datetime(2023, 5, 23, 22, 7), 'price': 5054.4945, 'commission': 1.51634835, 'value': -5054.4945, 'size': -1, 'type': 'sell', 'ref': 125}
# {'datetime': datetime.datetime(2023, 5, 23, 22, 25), 'price': 5048.0, 'commission': 1.5144, 'value': -5054.4945, 'size': 1, 'type': 'buy', 'ref': 126}
# {'datetime': datetime.datetime(2023, 5, 23, 22, 28), 'price': 5045.0, 'commission': 1.5134999999999998, 'value': -5045.0, 'size': -1, 'type': 'sell', 'ref': 127}
# {'datetime': datetime.datetime(2023, 5, 23, 22, 29), 'price': 5049.5049, 'commission': 1.5148514699999998, 'value': -5045.0, 'size': 1, 'type': 'buy', 'ref': 128}
# {'datetime': datetime.datetime(2023, 5, 24, 7, 37), 'price': 5060.0, 'commission': 1.5179999999999998, 'value': -5060.0, 'size': -1, 'type': 'sell', 'ref': 129}
# {'datetime': datetime.datetime(2023, 5, 24, 9, 0), 'price': 5062.5062, 'commission': 1.5187518599999998, 'value': -5060.0, 'size': 1, 'type': 'buy', 'ref': 130}
# {'datetime': datetime.datetime(2023, 5, 24, 9, 2), 'price': 5058.4941, 'commission': 1.5175482299999998, 'value': -5058.4941, 'size': -1, 'type': 'sell', 'ref': 131}
# {'datetime': datetime.datetime(2023, 5, 24, 9, 15), 'price': 5058.5058, 'commission': 1.5175517399999998, 'value': -5058.4941, 'size': 1, 'type': 'buy', 'ref': 132}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 1), 'price': 5083.4916, 'commission': 1.52504748, 'value': -5083.4916, 'size': -1, 'type': 'sell', 'ref': 133}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 2), 'price': 5084.5084, 'commission': 1.5253525199999998, 'value': -5083.4916, 'size': 1, 'type': 'buy', 'ref': 134}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 4), 'price': 5084.4915, 'commission': 1.52534745, 'value': -5084.4915, 'size': -1, 'type': 'sell', 'ref': 135}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 6), 'price': 5089.0, 'commission': 1.5267, 'value': -5084.4915, 'size': 1, 'type': 'buy', 'ref': 136}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 7), 'price': 5084.4915, 'commission': 1.52534745, 'value': -5084.4915, 'size': -1, 'type': 'sell', 'ref': 137}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 29), 'price': 5087.5087, 'commission': 1.52625261, 'value': -5084.4915, 'size': 1, 'type': 'buy', 'ref': 138}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 36), 'price': 5084.4915, 'commission': 1.52534745, 'value': -5084.4915, 'size': -1, 'type': 'sell', 'ref': 139}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 46), 'price': 5087.5087, 'commission': 1.52625261, 'value': -5084.4915, 'size': 1, 'type': 'buy', 'ref': 140}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 48), 'price': 5085.0, 'commission': 1.5254999999999999, 'value': -5085.0, 'size': -1, 'type': 'sell', 'ref': 141}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 50), 'price': 5088.0, 'commission': 1.5263999999999998, 'value': -5085.0, 'size': 1, 'type': 'buy', 'ref': 142}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 51), 'price': 5085.4914, 'commission': 1.5256474199999999, 'value': -5085.4914, 'size': -1, 'type': 'sell', 'ref': 143}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 52), 'price': 5088.0, 'commission': 1.5263999999999998, 'value': -5085.4914, 'size': 1, 'type': 'buy', 'ref': 144}
# {'datetime': datetime.datetime(2023, 5, 24, 10, 59), 'price': 5085.4914, 'commission': 1.5256474199999999, 'value': -5085.4914, 'size': -1, 'type': 'sell', 'ref': 145}
# {'datetime': datetime.datetime(2023, 5, 24, 11, 0), 'price': 5088.0, 'commission': 1.5263999999999998, 'value': -5085.4914, 'size': 1, 'type': 'buy', 'ref': 146}
# {'datetime': datetime.datetime(2023, 5, 24, 11, 3), 'price': 5085.4914, 'commission': 1.5256474199999999, 'value': -5085.4914, 'size': -1, 'type': 'sell', 'ref': 147}
# {'datetime': datetime.datetime(2023, 5, 24, 11, 6), 'price': 5088.5088, 'commission': 1.5265526399999998, 'value': -5085.4914, 'size': 1, 'type': 'buy', 'ref': 148}
# {'datetime': datetime.datetime(2023, 5, 24, 11, 24), 'price': 5089.491, 'commission': 1.5268472999999998, 'value': -5089.491, 'size': -1, 'type': 'sell', 'ref': 149}
# {'datetime': datetime.datetime(2023, 5, 24, 11, 29), 'price': 5094.0, 'commission': 1.5281999999999998, 'value': -5089.491, 'size': 1, 'type': 'buy', 'ref': 150}
# {'datetime': datetime.datetime(2023, 5, 24, 13, 39), 'price': 5093.4906, 'commission': 1.52804718, 'value': -5093.4906, 'size': -1, 'type': 'sell', 'ref': 151}
# {'datetime': datetime.datetime(2023, 5, 24, 13, 41), 'price': 5097.5097, 'commission': 1.5292529099999999, 'value': -5093.4906, 'size': 1, 'type': 'buy', 'ref': 152}
# {'datetime': datetime.datetime(2023, 5, 24, 13, 43), 'price': 5093.4906, 'commission': 1.52804718, 'value': -5093.4906, 'size': -1, 'type': 'sell', 'ref': 153}
# {'datetime': datetime.datetime(2023, 5, 24, 13, 44), 'price': 5096.0, 'commission': 1.5288, 'value': -5093.4906, 'size': 1, 'type': 'buy', 'ref': 154}
# {'datetime': datetime.datetime(2023, 5, 24, 13, 45), 'price': 5090.4909, 'commission': 1.5271472699999997, 'value': -5090.4909, 'size': -1, 'type': 'sell', 'ref': 155}
# {'datetime': datetime.datetime(2023, 5, 24, 13, 50), 'price': 5097.5097, 'commission': 1.5292529099999999, 'value': -5090.4909, 'size': 1, 'type': 'buy', 'ref': 156}
# {'datetime': datetime.datetime(2023, 5, 24, 14, 15), 'price': 5101.4898, 'commission': 1.53044694, 'value': -5101.4898, 'size': -1, 'type': 'sell', 'ref': 157}
# {'datetime': datetime.datetime(2023, 5, 24, 14, 44), 'price': 5086.5086, 'commission': 1.52595258, 'value': -5101.4898, 'size': 1, 'type': 'buy', 'ref': 158}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 0), 'price': 5087.4912, 'commission': 1.52624736, 'value': -5087.4912, 'size': -1, 'type': 'sell', 'ref': 159}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 12), 'price': 5089.5089, 'commission': 1.5268526699999998, 'value': -5087.4912, 'size': 1, 'type': 'buy', 'ref': 160}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 18), 'price': 5085.4914, 'commission': 1.5256474199999999, 'value': -5085.4914, 'size': -1, 'type': 'sell', 'ref': 161}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 19), 'price': 5087.5087, 'commission': 1.52625261, 'value': -5085.4914, 'size': 1, 'type': 'buy', 'ref': 162}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 29), 'price': 5087.0, 'commission': 1.5260999999999998, 'value': -5087.0, 'size': -1, 'type': 'sell', 'ref': 163}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 32), 'price': 5091.5091, 'commission': 1.52745273, 'value': -5087.0, 'size': 1, 'type': 'buy', 'ref': 164}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 34), 'price': 5089.0, 'commission': 1.5267, 'value': -5089.0, 'size': -1, 'type': 'sell', 'ref': 165}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 35), 'price': 5090.0, 'commission': 1.527, 'value': -5089.0, 'size': 1, 'type': 'buy', 'ref': 166}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 36), 'price': 5084.0, 'commission': 1.5252, 'value': -5084.0, 'size': -1, 'type': 'sell', 'ref': 167}
# {'datetime': datetime.datetime(2023, 5, 24, 21, 51), 'price': 5085.5085, 'commission': 1.5256525499999998, 'value': -5084.0, 'size': 1, 'type': 'buy', 'ref': 168}
# {'datetime': datetime.datetime(2023, 5, 24, 22, 22), 'price': 5096.0, 'commission': 1.5288, 'value': -5096.0, 'size': -1, 'type': 'sell', 'ref': 169}
# {'datetime': datetime.datetime(2023, 5, 24, 22, 29), 'price': 5101.5100999999995, 'commission': 1.5304530299999997, 'value': -5096.0, 'size': 1, 'type': 'buy', 'ref': 170}
# {'datetime': datetime.datetime(2023, 5, 24, 22, 39), 'price': 5100.4899000000005, 'commission': 1.53014697, 'value': -5100.4899000000005, 'size': -1, 'type': 'sell', 'ref': 171}
# {'datetime': datetime.datetime(2023, 5, 24, 22, 54), 'price': 5100.51, 'commission': 1.5301529999999999, 'value': -5100.4899000000005, 'size': 1, 'type': 'buy', 'ref': 172}
# {'datetime': datetime.datetime(2023, 5, 25, 9, 0), 'price': 5094.4905, 'commission': 1.5283471499999999, 'value': -5094.4905, 'size': -1, 'type': 'sell', 'ref': 173}
# {'datetime': datetime.datetime(2023, 5, 25, 9, 7), 'price': 5097.0, 'commission': 1.5291, 'value': -5094.4905, 'size': 1, 'type': 'buy', 'ref': 174}
# {'datetime': datetime.datetime(2023, 5, 25, 9, 8), 'price': 5091.4908000000005, 'commission': 1.52744724, 'value': -5091.4908000000005, 'size': -1, 'type': 'sell', 'ref': 175}
# {'datetime': datetime.datetime(2023, 5, 25, 9, 22), 'price': 5087.5087, 'commission': 1.52625261, 'value': -5091.4908000000005, 'size': 1, 'type': 'buy', 'ref': 176}
# {'datetime': datetime.datetime(2023, 5, 25, 9, 23), 'price': 5084.4915, 'commission': 1.52534745, 'value': -5084.4915, 'size': -1, 'type': 'sell', 'ref': 177}
# {'datetime': datetime.datetime(2023, 5, 25, 9, 24), 'price': 5091.0, 'commission': 1.5272999999999999, 'value': -5084.4915, 'size': 1, 'type': 'buy', 'ref': 178}
# {'datetime': datetime.datetime(2023, 5, 25, 9, 37), 'price': 5088.4911, 'commission': 1.5265473299999999, 'value': -5088.4911, 'size': -1, 'type': 'sell', 'ref': 179}
# {'datetime': datetime.datetime(2023, 5, 25, 10, 33), 'price': 5062.5062, 'commission': 1.5187518599999998, 'value': -5088.4911, 'size': 1, 'type': 'buy', 'ref': 180}
# {'datetime': datetime.datetime(2023, 5, 25, 10, 48), 'price': 5067.4932, 'commission': 1.5202479599999998, 'value': -5067.4932, 'size': -1, 'type': 'sell', 'ref': 181}
# {'datetime': datetime.datetime(2023, 5, 25, 11, 14), 'price': 5058.5058, 'commission': 1.5175517399999998, 'value': -5067.4932, 'size': 1, 'type': 'buy', 'ref': 182}
# {'datetime': datetime.datetime(2023, 5, 25, 11, 22), 'price': 5055.0, 'commission': 1.5165, 'value': -5055.0, 'size': -1, 'type': 'sell', 'ref': 183}
# {'datetime': datetime.datetime(2023, 5, 25, 11, 25), 'price': 5058.5058, 'commission': 1.5175517399999998, 'value': -5055.0, 'size': 1, 'type': 'buy', 'ref': 184}
# {'datetime': datetime.datetime(2023, 5, 25, 13, 29), 'price': 5057.4942, 'commission': 1.51724826, 'value': -5057.4942, 'size': -1, 'type': 'sell', 'ref': 185}
# {'datetime': datetime.datetime(2023, 5, 25, 13, 33), 'price': 5059.5059, 'commission': 1.5178517699999998, 'value': -5057.4942, 'size': 1, 'type': 'buy', 'ref': 186}
# {'datetime': datetime.datetime(2023, 5, 25, 13, 37), 'price': 5056.4943, 'commission': 1.51694829, 'value': -5056.4943, 'size': -1, 'type': 'sell', 'ref': 187}
# {'datetime': datetime.datetime(2023, 5, 25, 13, 57), 'price': 5053.5053, 'commission': 1.5160515899999998, 'value': -5056.4943, 'size': 1, 'type': 'buy', 'ref': 188}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 4), 'price': 5051.4948, 'commission': 1.51544844, 'value': -5051.4948, 'size': -1, 'type': 'sell', 'ref': 189}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 12), 'price': 5054.5054, 'commission': 1.5163516199999998, 'value': -5051.4948, 'size': 1, 'type': 'buy', 'ref': 190}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 13), 'price': 5051.4948, 'commission': 1.51544844, 'value': -5051.4948, 'size': -1, 'type': 'sell', 'ref': 191}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 16), 'price': 5053.5053, 'commission': 1.5160515899999998, 'value': -5051.4948, 'size': 1, 'type': 'buy', 'ref': 192}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 21), 'price': 5053.0, 'commission': 1.5158999999999998, 'value': -5053.0, 'size': -1, 'type': 'sell', 'ref': 193}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 22), 'price': 5054.0, 'commission': 1.5161999999999998, 'value': -5053.0, 'size': 1, 'type': 'buy', 'ref': 194}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 31), 'price': 5051.4948, 'commission': 1.51544844, 'value': -5051.4948, 'size': -1, 'type': 'sell', 'ref': 195}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 32), 'price': 5056.0, 'commission': 1.5168, 'value': -5051.4948, 'size': 1, 'type': 'buy', 'ref': 196}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 33), 'price': 5052.4947, 'commission': 1.5157484099999998, 'value': -5052.4947, 'size': -1, 'type': 'sell', 'ref': 197}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 53), 'price': 5056.5055999999995, 'commission': 1.5169516799999998, 'value': -5052.4947, 'size': 1, 'type': 'buy', 'ref': 198}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 58), 'price': 5048.4951, 'commission': 1.51454853, 'value': -5048.4951, 'size': -1, 'type': 'sell', 'ref': 199}
# {'datetime': datetime.datetime(2023, 5, 25, 14, 59), 'price': 5049.5049, 'commission': 1.5148514699999998, 'value': -5048.4951, 'size': 1, 'type': 'buy', 'ref': 200}
# {'datetime': datetime.datetime(2023, 5, 25, 15, 1), 'price': 5049.0, 'commission': 1.5147, 'value': -5049.0, 'size': -1, 'type': 'sell', 'ref': 201}
# {'datetime': datetime.datetime(2023, 5, 25, 21, 34), 'price': 5018.5018, 'commission': 1.5055505399999998, 'value': -5049.0, 'size': 1, 'type': 'buy', 'ref': 202}
# {'datetime': datetime.datetime(2023, 5, 25, 21, 47), 'price': 5019.0, 'commission': 1.5056999999999998, 'value': -5019.0, 'size': -1, 'type': 'sell', 'ref': 203}
# {'datetime': datetime.datetime(2023, 5, 25, 21, 56), 'price': 5022.5022, 'commission': 1.5067506599999998, 'value': -5019.0, 'size': 1, 'type': 'buy', 'ref': 204}
# {'datetime': datetime.datetime(2023, 5, 25, 21, 58), 'price': 5019.4980000000005, 'commission': 1.5058494, 'value': -5019.4980000000005, 'size': -1, 'type': 'sell', 'ref': 205}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 29), 'price': 5007.5007, 'commission': 1.5022502099999997, 'value': -5019.4980000000005, 'size': 1, 'type': 'buy', 'ref': 206}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 30), 'price': 5002.4997, 'commission': 1.50074991, 'value': -5002.4997, 'size': -1, 'type': 'sell', 'ref': 207}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 33), 'price': 5004.5004, 'commission': 1.50135012, 'value': -5002.4997, 'size': 1, 'type': 'buy', 'ref': 208}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 38), 'price': 5003.4996, 'commission': 1.5010498799999998, 'value': -5003.4996, 'size': -1, 'type': 'sell', 'ref': 209}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 39), 'price': 5006.5006, 'commission': 1.50195018, 'value': -5003.4996, 'size': 1, 'type': 'buy', 'ref': 210}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 47), 'price': 5004.4995, 'commission': 1.5013498499999998, 'value': -5004.4995, 'size': -1, 'type': 'sell', 'ref': 211}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 51), 'price': 5007.5007, 'commission': 1.5022502099999997, 'value': -5004.4995, 'size': 1, 'type': 'buy', 'ref': 212}
# {'datetime': datetime.datetime(2023, 5, 25, 22, 52), 'price': 5003.4996, 'commission': 1.5010498799999998, 'value': -5003.4996, 'size': -1, 'type': 'sell', 'ref': 213}
# {'datetime': datetime.datetime(2023, 5, 26, 7, 31), 'price': 5006.0, 'commission': 1.5017999999999998, 'value': -5003.4996, 'size': 1, 'type': 'buy', 'ref': 214}
# {'datetime': datetime.datetime(2023, 5, 26, 9, 25), 'price': 5029.0, 'commission': 1.5087, 'value': -5029.0, 'size': -1, 'type': 'sell', 'ref': 215}
# {'datetime': datetime.datetime(2023, 5, 26, 9, 41), 'price': 5031.5031, 'commission': 1.5094509299999999, 'value': -5029.0, 'size': 1, 'type': 'buy', 'ref': 216}
# {'datetime': datetime.datetime(2023, 5, 26, 9, 53), 'price': 5027.4972, 'commission': 1.5082491599999999, 'value': -5027.4972, 'size': -1, 'type': 'sell', 'ref': 217}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 14), 'price': 5019.0, 'commission': 1.5056999999999998, 'value': -5027.4972, 'size': 1, 'type': 'buy', 'ref': 218}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 33), 'price': 5015.4984, 'commission': 1.50464952, 'value': -5015.4984, 'size': -1, 'type': 'sell', 'ref': 219}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 35), 'price': 5019.5019, 'commission': 1.50585057, 'value': -5015.4984, 'size': 1, 'type': 'buy', 'ref': 220}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 38), 'price': 5015.4984, 'commission': 1.50464952, 'value': -5015.4984, 'size': -1, 'type': 'sell', 'ref': 221}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 46), 'price': 5017.5017, 'commission': 1.5052505099999998, 'value': -5015.4984, 'size': 1, 'type': 'buy', 'ref': 222}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 48), 'price': 5015.4984, 'commission': 1.50464952, 'value': -5015.4984, 'size': -1, 'type': 'sell', 'ref': 223}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 49), 'price': 5017.0, 'commission': 1.5050999999999999, 'value': -5015.4984, 'size': 1, 'type': 'buy', 'ref': 224}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 50), 'price': 5014.4985, 'commission': 1.5043495499999997, 'value': -5014.4985, 'size': -1, 'type': 'sell', 'ref': 225}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 54), 'price': 5016.5016, 'commission': 1.5049504799999998, 'value': -5014.4985, 'size': 1, 'type': 'buy', 'ref': 226}
# {'datetime': datetime.datetime(2023, 5, 26, 10, 59), 'price': 5015.4984, 'commission': 1.50464952, 'value': -5015.4984, 'size': -1, 'type': 'sell', 'ref': 227}
# {'datetime': datetime.datetime(2023, 5, 26, 11, 15), 'price': 5012.5012, 'commission': 1.5037503599999997, 'value': -5015.4984, 'size': 1, 'type': 'buy', 'ref': 228}
# {'datetime': datetime.datetime(2023, 5, 26, 13, 41), 'price': 5028.4971000000005, 'commission': 1.50854913, 'value': -5028.4971000000005, 'size': -1, 'type': 'sell', 'ref': 229}
# {'datetime': datetime.datetime(2023, 5, 26, 13, 53), 'price': 5030.503, 'commission': 1.5091508999999999, 'value': -5028.4971000000005, 'size': 1, 'type': 'buy', 'ref': 230}
# {'datetime': datetime.datetime(2023, 5, 26, 14, 16), 'price': 5034.4965, 'commission': 1.51034895, 'value': -5034.4965, 'size': -1, 'type': 'sell', 'ref': 231}
# {'datetime': datetime.datetime(2023, 5, 26, 14, 24), 'price': 5038.5037999999995, 'commission': 1.5115511399999997, 'value': -5034.4965, 'size': 1, 'type': 'buy', 'ref': 232}
# {'datetime': datetime.datetime(2023, 5, 26, 14, 45), 'price': 5040.4959, 'commission': 1.5121487699999998, 'value': -5040.4959, 'size': -1, 'type': 'sell', 'ref': 233}
# {'datetime': datetime.datetime(2023, 5, 26, 14, 54), 'price': 5044.5044, 'commission': 1.5133513199999997, 'value': -5040.4959, 'size': 1, 'type': 'buy', 'ref': 234}
# {'datetime': datetime.datetime(2023, 5, 26, 15, 1), 'price': 5039.0, 'commission': 1.5116999999999998, 'value': -5039.0, 'size': -1, 'type': 'sell', 'ref': 235}
# {'datetime': datetime.datetime(2023, 5, 26, 21, 0), 'price': 5043.5043, 'commission': 1.5130512899999997, 'value': -5039.0, 'size': 1, 'type': 'buy', 'ref': 236}
# {'datetime': datetime.datetime(2023, 5, 26, 21, 2), 'price': 5036.4963, 'commission': 1.5109488899999999, 'value': -5036.4963, 'size': -1, 'type': 'sell', 'ref': 237}
# {'datetime': datetime.datetime(2023, 5, 26, 21, 55), 'price': 4986.4986, 'commission': 1.4959495799999998, 'value': -5036.4963, 'size': 1, 'type': 'buy', 'ref': 238}
# {'datetime': datetime.datetime(2023, 5, 26, 22, 5), 'price': 4981.0, 'commission': 1.4943, 'value': -4981.0, 'size': -1, 'type': 'sell', 'ref': 239}
# {'datetime': datetime.datetime(2023, 5, 26, 22, 23), 'price': 4979.4979, 'commission': 1.49384937, 'value': -4981.0, 'size': 1, 'type': 'buy', 'ref': 240}
# {'datetime': datetime.datetime(2023, 5, 26, 22, 32), 'price': 4975.5024, 'commission': 1.4926507199999999, 'value': -4975.5024, 'size': -1, 'type': 'sell', 'ref': 241}
# {'datetime': datetime.datetime(2023, 5, 26, 22, 49), 'price': 4974.0, 'commission': 1.4922, 'value': -4975.5024, 'size': 1, 'type': 'buy', 'ref': 242}
# {'datetime': datetime.datetime(2023, 5, 26, 22, 51), 'price': 4971.5028, 'commission': 1.49145084, 'value': -4971.5028, 'size': -1, 'type': 'sell', 'ref': 243}
# {'datetime': datetime.datetime(2023, 5, 26, 22, 54), 'price': 4973.4973, 'commission': 1.49204919, 'value': -4971.5028, 'size': 1, 'type': 'buy', 'ref': 244}
# {'datetime': datetime.datetime(2023, 5, 30, 9, 16), 'price': 5068.0, 'commission': 1.5204, 'value': -5068.0, 'size': -1, 'type': 'sell', 'ref': 245}
# {'datetime': datetime.datetime(2023, 5, 30, 9, 17), 'price': 5072.5072, 'commission': 1.52175216, 'value': -5068.0, 'size': 1, 'type': 'buy', 'ref': 246}
# {'datetime': datetime.datetime(2023, 5, 30, 9, 19), 'price': 5067.4932, 'commission': 1.5202479599999998, 'value': -5067.4932, 'size': -1, 'type': 'sell', 'ref': 247}
# {'datetime': datetime.datetime(2023, 5, 30, 9, 29), 'price': 5069.5069, 'commission': 1.52085207, 'value': -5067.4932, 'size': 1, 'type': 'buy', 'ref': 248}
# {'datetime': datetime.datetime(2023, 5, 30, 10, 5), 'price': 5076.4923, 'commission': 1.5229476899999999, 'value': -5076.4923, 'size': -1, 'type': 'sell', 'ref': 249}
# {'datetime': datetime.datetime(2023, 5, 30, 10, 30), 'price': 5079.5079, 'commission': 1.5238523699999997, 'value': -5076.4923, 'size': 1, 'type': 'buy', 'ref': 250}
# {'datetime': datetime.datetime(2023, 5, 30, 10, 31), 'price': 5076.4923, 'commission': 1.5229476899999999, 'value': -5076.4923, 'size': -1, 'type': 'sell', 'ref': 251}
# {'datetime': datetime.datetime(2023, 5, 30, 10, 32), 'price': 5078.5078, 'commission': 1.52355234, 'value': -5076.4923, 'size': 1, 'type': 'buy', 'ref': 252}
# {'datetime': datetime.datetime(2023, 5, 30, 10, 46), 'price': 5077.4922, 'commission': 1.5232476599999998, 'value': -5077.4922, 'size': -1, 'type': 'sell', 'ref': 253}
# {'datetime': datetime.datetime(2023, 5, 30, 10, 48), 'price': 5079.5079, 'commission': 1.5238523699999997, 'value': -5077.4922, 'size': 1, 'type': 'buy', 'ref': 254}
# {'datetime': datetime.datetime(2023, 5, 30, 10, 53), 'price': 5077.4922, 'commission': 1.5232476599999998, 'value': -5077.4922, 'size': -1, 'type': 'sell', 'ref': 255}
# {'datetime': datetime.datetime(2023, 5, 30, 11, 21), 'price': 5071.5071, 'commission': 1.52145213, 'value': -5077.4922, 'size': 1, 'type': 'buy', 'ref': 256}
# {'datetime': datetime.datetime(2023, 5, 30, 11, 29), 'price': 5068.0, 'commission': 1.5204, 'value': -5068.0, 'size': -1, 'type': 'sell', 'ref': 257}
# {'datetime': datetime.datetime(2023, 5, 30, 13, 29), 'price': 5068.0, 'commission': 1.5204, 'value': -5068.0, 'size': 1, 'type': 'buy', 'ref': 258}
# {'datetime': datetime.datetime(2023, 5, 30, 13, 30), 'price': 5066.4933, 'commission': 1.51994799, 'value': -5066.4933, 'size': -1, 'type': 'sell', 'ref': 259}
# {'datetime': datetime.datetime(2023, 5, 30, 13, 32), 'price': 5070.0, 'commission': 1.521, 'value': -5066.4933, 'size': 1, 'type': 'buy', 'ref': 260}
# {'datetime': datetime.datetime(2023, 5, 30, 13, 33), 'price': 5066.4933, 'commission': 1.51994799, 'value': -5066.4933, 'size': -1, 'type': 'sell', 'ref': 261}
# {'datetime': datetime.datetime(2023, 5, 30, 13, 53), 'price': 5068.5068, 'commission': 1.5205520399999999, 'value': -5066.4933, 'size': 1, 'type': 'buy', 'ref': 262}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 6), 'price': 5065.4934, 'commission': 1.51964802, 'value': -5065.4934, 'size': -1, 'type': 'sell', 'ref': 263}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 7), 'price': 5067.0, 'commission': 1.5200999999999998, 'value': -5065.4934, 'size': 1, 'type': 'buy', 'ref': 264}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 8), 'price': 5064.4935000000005, 'commission': 1.51934805, 'value': -5064.4935000000005, 'size': -1, 'type': 'sell', 'ref': 265}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 21), 'price': 5066.5066, 'commission': 1.5199519799999999, 'value': -5064.4935000000005, 'size': 1, 'type': 'buy', 'ref': 266}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 36), 'price': 5066.4933, 'commission': 1.51994799, 'value': -5066.4933, 'size': -1, 'type': 'sell', 'ref': 267}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 39), 'price': 5069.5069, 'commission': 1.52085207, 'value': -5066.4933, 'size': 1, 'type': 'buy', 'ref': 268}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 42), 'price': 5067.4932, 'commission': 1.5202479599999998, 'value': -5067.4932, 'size': -1, 'type': 'sell', 'ref': 269}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 44), 'price': 5069.5069, 'commission': 1.52085207, 'value': -5067.4932, 'size': 1, 'type': 'buy', 'ref': 270}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 46), 'price': 5068.4931, 'commission': 1.5205479299999998, 'value': -5068.4931, 'size': -1, 'type': 'sell', 'ref': 271}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 47), 'price': 5070.0, 'commission': 1.521, 'value': -5068.4931, 'size': 1, 'type': 'buy', 'ref': 272}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 49), 'price': 5067.4932, 'commission': 1.5202479599999998, 'value': -5067.4932, 'size': -1, 'type': 'sell', 'ref': 273}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 52), 'price': 5069.5069, 'commission': 1.52085207, 'value': -5067.4932, 'size': 1, 'type': 'buy', 'ref': 274}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 54), 'price': 5067.4932, 'commission': 1.5202479599999998, 'value': -5067.4932, 'size': -1, 'type': 'sell', 'ref': 275}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 56), 'price': 5071.5071, 'commission': 1.52145213, 'value': -5067.4932, 'size': 1, 'type': 'buy', 'ref': 276}
# {'datetime': datetime.datetime(2023, 5, 30, 14, 57), 'price': 5066.4933, 'commission': 1.51994799, 'value': -5066.4933, 'size': -1, 'type': 'sell', 'ref': 277}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 22), 'price': 5015.5015, 'commission': 1.50465045, 'value': -5066.4933, 'size': 1, 'type': 'buy', 'ref': 278}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 23), 'price': 5008.4991, 'commission': 1.50254973, 'value': -5008.4991, 'size': -1, 'type': 'sell', 'ref': 279}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 32), 'price': 5012.0, 'commission': 1.5035999999999998, 'value': -5008.4991, 'size': 1, 'type': 'buy', 'ref': 280}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 33), 'price': 5009.499, 'commission': 1.5028496999999998, 'value': -5009.499, 'size': -1, 'type': 'sell', 'ref': 281}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 34), 'price': 5012.5012, 'commission': 1.5037503599999997, 'value': -5009.499, 'size': 1, 'type': 'buy', 'ref': 282}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 35), 'price': 5010.4989000000005, 'commission': 1.50314967, 'value': -5010.4989000000005, 'size': -1, 'type': 'sell', 'ref': 283}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 37), 'price': 5016.5016, 'commission': 1.5049504799999998, 'value': -5010.4989000000005, 'size': 1, 'type': 'buy', 'ref': 284}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 50), 'price': 5013.4986, 'commission': 1.5040495799999998, 'value': -5013.4986, 'size': -1, 'type': 'sell', 'ref': 285}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 51), 'price': 5016.0, 'commission': 1.5048, 'value': -5013.4986, 'size': 1, 'type': 'buy', 'ref': 286}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 52), 'price': 5011.4988, 'commission': 1.50344964, 'value': -5011.4988, 'size': -1, 'type': 'sell', 'ref': 287}
# {'datetime': datetime.datetime(2023, 5, 30, 21, 58), 'price': 5019.0, 'commission': 1.5056999999999998, 'value': -5011.4988, 'size': 1, 'type': 'buy', 'ref': 288}
# {'datetime': datetime.datetime(2023, 5, 30, 22, 2), 'price': 5013.4986, 'commission': 1.5040495799999998, 'value': -5013.4986, 'size': -1, 'type': 'sell', 'ref': 289}
# {'datetime': datetime.datetime(2023, 5, 30, 22, 7), 'price': 5015.5015, 'commission': 1.50465045, 'value': -5013.4986, 'size': 1, 'type': 'buy', 'ref': 290}
# {'datetime': datetime.datetime(2023, 5, 30, 22, 8), 'price': 5014.0, 'commission': 1.5041999999999998, 'value': -5014.0, 'size': -1, 'type': 'sell', 'ref': 291}
# {'datetime': datetime.datetime(2023, 5, 30, 22, 9), 'price': 5017.5017, 'commission': 1.5052505099999998, 'value': -5014.0, 'size': 1, 'type': 'buy', 'ref': 292}
# {'datetime': datetime.datetime(2023, 5, 30, 22, 21), 'price': 5015.4984, 'commission': 1.50464952, 'value': -5015.4984, 'size': -1, 'type': 'sell', 'ref': 293}
# {'datetime': datetime.datetime(2023, 5, 30, 22, 48), 'price': 4991.4991, 'commission': 1.4974497299999998, 'value': -5015.4984, 'size': 1, 'type': 'buy', 'ref': 294}
# {'datetime': datetime.datetime(2023, 5, 31, 7, 31), 'price': 4991.0, 'commission': 1.4972999999999999, 'value': -4991.0, 'size': -1, 'type': 'sell', 'ref': 295}
# {'datetime': datetime.datetime(2023, 5, 31, 9, 5), 'price': 4992.4992, 'commission': 1.4977497599999998, 'value': -4991.0, 'size': 1, 'type': 'buy', 'ref': 296}
# {'datetime': datetime.datetime(2023, 5, 31, 9, 8), 'price': 4983.5016000000005, 'commission': 1.49505048, 'value': -4983.5016000000005, 'size': -1, 'type': 'sell', 'ref': 297}
# ...
# {'datetime': datetime.datetime(2023, 5, 31, 10, 48), 'price': 4984.0, 'commission': 1.4951999999999999, 'value': -4984.0, 'size': -1, 'type': 'sell', 'ref': 313}
# {'datetime': datetime.datetime(2023, 5, 31, 10, 49), 'price': 4986.4986, 'commission': 1.4959495799999998, 'value': -4984.0, 'size': 1, 'type': 'buy', 'ref': 314}
# {'datetime': datetime.datetime(2023, 5, 31, 10, 55), 'price': 4983.5016000000005, 'commission': 1.49505048, 'value': -4983.5016000000005, 'size': -1, 'type': 'sell', 'ref': 315}
# {'datetime': datetime.datetime(2023, 5, 31, 10, 57), 'price': 4986.0, 'commission': 1.4957999999999998, 'value': -4983.5016000000005, 'size': 1, 'type': 'buy', 'ref': 316}
# {'datetime': datetime.datetime(2023, 5, 31, 10, 58), 'price': 4980.5019, 'commission': 1.49415057, 'value': -4980.5019, 'size': -1, 'type': 'sell', 'ref': 317}
# {'datetime': datetime.datetime(2023, 5, 31, 11, 18), 'price': 4982.4982, 'commission': 1.49474946, 'value': -4980.5019, 'size': 1, 'type': 'buy', 'ref': 318}
# {'datetime': datetime.datetime(2023, 5, 31, 11, 21), 'price': 4981.0, 'commission': 1.4943, 'value': -4981.0, 'size': -1, 'type': 'sell', 'ref': 319}
# {'datetime': datetime.datetime(2023, 5, 31, 11, 22), 'price': 4986.4986, 'commission': 1.4959495799999998, 'value': -4981.0, 'size': 1, 'type': 'buy', 'ref': 320}
# {'datetime': datetime.datetime(2023, 5, 31, 11, 27), 'price': 4981.5018, 'commission': 1.4944505399999999, 'value': -4981.5018, 'size': -1, 'type': 'sell', 'ref': 321}
# {'datetime': datetime.datetime(2023, 5, 31, 13, 45), 'price': 4980.498, 'commission': 1.4941493999999997, 'value': -4981.5018, 'size': 1, 'type': 'buy', 'ref': 322}
# {'datetime': datetime.datetime(2023, 5, 31, 13, 47), 'price': 4976.5023, 'commission': 1.4929506899999998, 'value': -4976.5023, 'size': -1, 'type': 'sell', 'ref': 323}
# {'datetime': datetime.datetime(2023, 5, 31, 13, 49), 'price': 4980.498, 'commission': 1.4941493999999997, 'value': -4976.5023, 'size': 1, 'type': 'buy', 'ref': 324}
# {'datetime': datetime.datetime(2023, 5, 31, 14, 11), 'price': 4988.5011, 'commission': 1.49655033, 'value': -4988.5011, 'size': -1, 'type': 'sell', 'ref': 325}
# {'datetime': datetime.datetime(2023, 5, 31, 14, 38), 'price': 4986.0, 'commission': 1.4957999999999998, 'value': -4988.5011, 'size': 1, 'type': 'buy', 'ref': 326}
# {'datetime': datetime.datetime(2023, 5, 31, 14, 43), 'price': 4981.5018, 'commission': 1.4944505399999999, 'value': -4981.5018, 'size': -1, 'type': 'sell', 'ref': 327}
# {'datetime': datetime.datetime(2023, 5, 31, 14, 46), 'price': 4983.4983, 'commission': 1.49504949, 'value': -4981.5018, 'size': 1, 'type': 'buy', 'ref': 328}
# {'datetime': datetime.datetime(2023, 5, 31, 14, 56), 'price': 4986.5013, 'commission': 1.4959503899999997, 'value': -4986.5013, 'size': -1, 'type': 'sell', 'ref': 329}
# {'datetime': datetime.datetime(2023, 5, 31, 21, 0), 'price': 4990.499, 'commission': 1.4971496999999998, 'value': -4986.5013, 'size': 1, 'type': 'buy', 'ref': 330}
# {'datetime': datetime.datetime(2023, 5, 31, 21, 8), 'price': 4987.0, 'commission': 1.4960999999999998, 'value': -4987.0, 'size': -1, 'type': 'sell', 'ref': 331}
# {'datetime': datetime.datetime(2023, 5, 31, 21, 9), 'price': 4995.4995, 'commission': 1.4986498499999998, 'value': -4987.0, 'size': 1, 'type': 'buy', 'ref': 332}
# {'datetime': datetime.datetime(2023, 5, 31, 21, 49), 'price': 5013.4986, 'commission': 1.5040495799999998, 'value': -5013.4986, 'size': -1, 'type': 'sell', 'ref': 333}
# {'datetime': datetime.datetime(2023, 5, 31, 21, 50), 'price': 5016.5016, 'commission': 1.5049504799999998, 'value': -5013.4986, 'size': 1, 'type': 'buy', 'ref': 334}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 16), 'price': 5031.4968, 'commission': 1.5094490399999998, 'value': -5031.4968, 'size': -1, 'type': 'sell', 'ref': 335}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 18), 'price': 5038.5037999999995, 'commission': 1.5115511399999997, 'value': -5031.4968, 'size': 1, 'type': 'buy', 'ref': 336}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 29), 'price': 5036.4963, 'commission': 1.5109488899999999, 'value': -5036.4963, 'size': -1, 'type': 'sell', 'ref': 337}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 35), 'price': 5038.0, 'commission': 1.5113999999999999, 'value': -5036.4963, 'size': 1, 'type': 'buy', 'ref': 338}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 42), 'price': 5039.0, 'commission': 1.5116999999999998, 'value': -5039.0, 'size': -1, 'type': 'sell', 'ref': 339}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 43), 'price': 5042.5042, 'commission': 1.51275126, 'value': -5039.0, 'size': 1, 'type': 'buy', 'ref': 340}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 49), 'price': 5038.0, 'commission': 1.5113999999999999, 'value': -5038.0, 'size': -1, 'type': 'sell', 'ref': 341}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 50), 'price': 5045.5045, 'commission': 1.51365135, 'value': -5038.0, 'size': 1, 'type': 'buy', 'ref': 342}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 58), 'price': 5042.4957, 'commission': 1.5127487099999999, 'value': -5042.4957, 'size': -1, 'type': 'sell', 'ref': 343}
# {'datetime': datetime.datetime(2023, 5, 31, 22, 59), 'price': 5045.5045, 'commission': 1.51365135, 'value': -5042.4957, 'size': 1, 'type': 'buy', 'ref': 344}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 0), 'price': 5039.496, 'commission': 1.5118487999999999, 'value': -5039.496, 'size': -1, 'type': 'sell', 'ref': 345}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 10), 'price': 5040.504, 'commission': 1.5121512, 'value': -5039.496, 'size': 1, 'type': 'buy', 'ref': 346}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 22), 'price': 5038.4961, 'commission': 1.51154883, 'value': -5038.4961, 'size': -1, 'type': 'sell', 'ref': 347}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 29), 'price': 5041.0, 'commission': 1.5123, 'value': -5038.4961, 'size': 1, 'type': 'buy', 'ref': 348}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 31), 'price': 5038.0, 'commission': 1.5113999999999999, 'value': -5038.0, 'size': -1, 'type': 'sell', 'ref': 349}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 42), 'price': 5035.5035, 'commission': 1.5106510499999999, 'value': -5038.0, 'size': 1, 'type': 'buy', 'ref': 350}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 44), 'price': 5033.4966, 'commission': 1.51004898, 'value': -5033.4966, 'size': -1, 'type': 'sell', 'ref': 351}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 47), 'price': 5033.5033, 'commission': 1.5100509899999999, 'value': -5033.4966, 'size': 1, 'type': 'buy', 'ref': 352}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 48), 'price': 5033.0, 'commission': 1.5098999999999998, 'value': -5033.0, 'size': -1, 'type': 'sell', 'ref': 353}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 49), 'price': 5036.5036, 'commission': 1.51095108, 'value': -5033.0, 'size': 1, 'type': 'buy', 'ref': 354}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 52), 'price': 5030.0, 'commission': 1.509, 'value': -5030.0, 'size': -1, 'type': 'sell', 'ref': 355}
# {'datetime': datetime.datetime(2023, 6, 1, 9, 57), 'price': 5032.5032, 'commission': 1.5097509599999999, 'value': -5030.0, 'size': 1, 'type': 'buy', 'ref': 356}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 0), 'price': 5029.497, 'commission': 1.5088491, 'value': -5029.497, 'size': -1, 'type': 'sell', 'ref': 357}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 14), 'price': 5026.0, 'commission': 1.5077999999999998, 'value': -5029.497, 'size': 1, 'type': 'buy', 'ref': 358}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 15), 'price': 5024.0, 'commission': 1.5071999999999999, 'value': -5024.0, 'size': -1, 'type': 'sell', 'ref': 359}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 31), 'price': 5027.0, 'commission': 1.5080999999999998, 'value': -5024.0, 'size': 1, 'type': 'buy', 'ref': 360}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 32), 'price': 5022.4977, 'commission': 1.5067493099999998, 'value': -5022.4977, 'size': -1, 'type': 'sell', 'ref': 361}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 44), 'price': 5021.0, 'commission': 1.5063, 'value': -5022.4977, 'size': 1, 'type': 'buy', 'ref': 362}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 45), 'price': 5019.4980000000005, 'commission': 1.5058494, 'value': -5019.4980000000005, 'size': -1, 'type': 'sell', 'ref': 363}
# {'datetime': datetime.datetime(2023, 6, 1, 10, 47), 'price': 5021.5021, 'commission': 1.5064506299999998, 'value': -5019.4980000000005, 'size': 1, 'type': 'buy', 'ref': 364}
# {'datetime': datetime.datetime(2023, 6, 1, 11, 12), 'price': 5032.0, 'commission': 1.5095999999999998, 'value': -5032.0, 'size': -1, 'type': 'sell', 'ref': 365}
# {'datetime': datetime.datetime(2023, 6, 1, 11, 20), 'price': 5036.5036, 'commission': 1.51095108, 'value': -5032.0, 'size': 1, 'type': 'buy', 'ref': 366}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 37), 'price': 5037.4962000000005, 'commission': 1.51124886, 'value': -5037.4962000000005, 'size': -1, 'type': 'sell', 'ref': 367}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 44), 'price': 5044.5044, 'commission': 1.5133513199999997, 'value': -5037.4962000000005, 'size': 1, 'type': 'buy', 'ref': 368}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 47), 'price': 5038.4961, 'commission': 1.51154883, 'value': -5038.4961, 'size': -1, 'type': 'sell', 'ref': 369}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 49), 'price': 5041.0, 'commission': 1.5123, 'value': -5038.4961, 'size': 1, 'type': 'buy', 'ref': 370}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 50), 'price': 5038.4961, 'commission': 1.51154883, 'value': -5038.4961, 'size': -1, 'type': 'sell', 'ref': 371}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 55), 'price': 5039.5039, 'commission': 1.5118511699999997, 'value': -5038.4961, 'size': 1, 'type': 'buy', 'ref': 372}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 57), 'price': 5037.0, 'commission': 1.5110999999999999, 'value': -5037.0, 'size': -1, 'type': 'sell', 'ref': 373}
# {'datetime': datetime.datetime(2023, 6, 1, 13, 58), 'price': 5040.504, 'commission': 1.5121512, 'value': -5037.0, 'size': 1, 'type': 'buy', 'ref': 374}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 2), 'price': 5037.4962000000005, 'commission': 1.51124886, 'value': -5037.4962000000005, 'size': -1, 'type': 'sell', 'ref': 375}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 9), 'price': 5038.5037999999995, 'commission': 1.5115511399999997, 'value': -5037.4962000000005, 'size': 1, 'type': 'buy', 'ref': 376}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 16), 'price': 5038.0, 'commission': 1.5113999999999999, 'value': -5038.0, 'size': -1, 'type': 'sell', 'ref': 377}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 18), 'price': 5040.504, 'commission': 1.5121512, 'value': -5038.0, 'size': 1, 'type': 'buy', 'ref': 378}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 19), 'price': 5036.4963, 'commission': 1.5109488899999999, 'value': -5036.4963, 'size': -1, 'type': 'sell', 'ref': 379}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 35), 'price': 5037.0, 'commission': 1.5110999999999999, 'value': -5036.4963, 'size': 1, 'type': 'buy', 'ref': 380}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 36), 'price': 5035.0, 'commission': 1.5105, 'value': -5035.0, 'size': -1, 'type': 'sell', 'ref': 381}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 38), 'price': 5039.5039, 'commission': 1.5118511699999997, 'value': -5035.0, 'size': 1, 'type': 'buy', 'ref': 382}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 42), 'price': 5036.0, 'commission': 1.5108, 'value': -5036.0, 'size': -1, 'type': 'sell', 'ref': 383}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 44), 'price': 5038.0, 'commission': 1.5113999999999999, 'value': -5036.0, 'size': 1, 'type': 'buy', 'ref': 384}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 46), 'price': 5036.0, 'commission': 1.5108, 'value': -5036.0, 'size': -1, 'type': 'sell', 'ref': 385}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 47), 'price': 5037.0, 'commission': 1.5110999999999999, 'value': -5036.0, 'size': 1, 'type': 'buy', 'ref': 386}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 48), 'price': 5035.0, 'commission': 1.5105, 'value': -5035.0, 'size': -1, 'type': 'sell', 'ref': 387}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 49), 'price': 5037.5037, 'commission': 1.51125111, 'value': -5035.0, 'size': 1, 'type': 'buy', 'ref': 388}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 51), 'price': 5030.4969, 'commission': 1.5091490699999999, 'value': -5030.4969, 'size': -1, 'type': 'sell', 'ref': 389}
# {'datetime': datetime.datetime(2023, 6, 1, 14, 58), 'price': 5039.5039, 'commission': 1.5118511699999997, 'value': -5030.4969, 'size': 1, 'type': 'buy', 'ref': 390}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 6), 'price': 5028.4971000000005, 'commission': 1.50854913, 'value': -5028.4971000000005, 'size': -1, 'type': 'sell', 'ref': 391}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 10), 'price': 5037.0, 'commission': 1.5110999999999999, 'value': -5028.4971000000005, 'size': 1, 'type': 'buy', 'ref': 392}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 12), 'price': 5035.4964, 'commission': 1.51064892, 'value': -5035.4964, 'size': -1, 'type': 'sell', 'ref': 393}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 19), 'price': 5034.0, 'commission': 1.5101999999999998, 'value': -5035.4964, 'size': 1, 'type': 'buy', 'ref': 394}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 20), 'price': 5030.4969, 'commission': 1.5091490699999999, 'value': -5030.4969, 'size': -1, 'type': 'sell', 'ref': 395}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 37), 'price': 5030.0, 'commission': 1.509, 'value': -5030.4969, 'size': 1, 'type': 'buy', 'ref': 396}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 39), 'price': 5027.0, 'commission': 1.5080999999999998, 'value': -5027.0, 'size': -1, 'type': 'sell', 'ref': 397}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 40), 'price': 5030.0, 'commission': 1.509, 'value': -5027.0, 'size': 1, 'type': 'buy', 'ref': 398}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 43), 'price': 5026.0, 'commission': 1.5077999999999998, 'value': -5026.0, 'size': -1, 'type': 'sell', 'ref': 399}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 44), 'price': 5029.0, 'commission': 1.5087, 'value': -5026.0, 'size': 1, 'type': 'buy', 'ref': 400}
# {'datetime': datetime.datetime(2023, 6, 1, 21, 45), 'price': 5025.4974, 'commission': 1.50764922, 'value': -5025.4974, 'size': -1, 'type': 'sell', 'ref': 401}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 15), 'price': 5014.5014, 'commission': 1.50435042, 'value': -5025.4974, 'size': 1, 'type': 'buy', 'ref': 402}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 24), 'price': 5010.0, 'commission': 1.503, 'value': -5010.0, 'size': -1, 'type': 'sell', 'ref': 403}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 28), 'price': 5013.5013, 'commission': 1.5040503899999997, 'value': -5010.0, 'size': 1, 'type': 'buy', 'ref': 404}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 30), 'price': 5005.4994, 'commission': 1.5016498199999997, 'value': -5005.4994, 'size': -1, 'type': 'sell', 'ref': 405}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 47), 'price': 5006.5006, 'commission': 1.50195018, 'value': -5005.4994, 'size': 1, 'type': 'buy', 'ref': 406}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 49), 'price': 5002.4997, 'commission': 1.50074991, 'value': -5002.4997, 'size': -1, 'type': 'sell', 'ref': 407}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 54), 'price': 5001.0, 'commission': 1.5003, 'value': -5002.4997, 'size': 1, 'type': 'buy', 'ref': 408}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 55), 'price': 4998.5001, 'commission': 1.49955003, 'value': -4998.5001, 'size': -1, 'type': 'sell', 'ref': 409}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 58), 'price': 5002.0, 'commission': 1.5006, 'value': -4998.5001, 'size': 1, 'type': 'buy', 'ref': 410}
# {'datetime': datetime.datetime(2023, 6, 1, 22, 59), 'price': 4998.5001, 'commission': 1.49955003, 'value': -4998.5001, 'size': -1, 'type': 'sell', 'ref': 411}

# %% [markdown]
# ## Trade Analysis

# %%
for k, v in trades.items():
    if isinstance(v, dict):
        for k2, v2 in v.items():
            print(f"{k}:{k2} - {v2}")
    else:
        print(f"{k} - {v}")# new comments testing github
# Out:
# total:total - 206
# total:open - 1
# total:closed - 205
# streak:won - AutoOrderedDict([('current', 0), ('longest', 2)])
# streak:lost - AutoOrderedDict([('current', 4), ('longest', 31)])
# pnl:gross - AutoOrderedDict([('total', -151.8168999999707), ('average', -0.7405702439022961)])
# pnl:net - AutoOrderedDict([('total', -772.5620447499704), ('average', -3.768595340243758)])
# won:total - 23
# won:pnl - AutoOrderedDict([('total', 296.07581563000383), ('average', 12.8728615491306), ('max', 47.967201559999786)])
# lost:total - 182
# lost:pnl - AutoOrderedDict([('total', -1068.6378603799742), ('average', -5.871636595494364), ('max', -19.528251409999502)])
# long:total - 0
# long:pnl - AutoOrderedDict([('total', 0.0), ('average', 0.0), ('won', AutoOrderedDict([('total', 0.0), ('average', 0.0), ('max', 0.0)])), ('lost', AutoOrderedDict([('total', 0.0), ('average', 0.0), ('max', 0.0)]))])
# long:won - 0
# long:lost - 0
# short:total - 205
# short:pnl - AutoOrderedDict([('total', -772.5620447499704), ('average', -3.768595340243758), ('won', AutoOrderedDict([('total', 296.07581563000383), ('average', 12.8728615491306), ('max', 47.967201559999786)])), ('lost', AutoOrderedDict([('total', -1068.6378603799742), ('average', -5.871636595494364), ('max', -19.528251409999502)]))])
# short:won - 23
# short:lost - 182
# len:total - 1590
# len:average - 7.7560975609756095
# len:max - 53
# len:min - 1
# len:won - AutoOrderedDict([('total', 604), ('average', 26.26086956521739), ('max', 53), ('min', 12)])
# len:lost - AutoOrderedDict([('total', 986), ('average', 5.417582417582418), ('max', 31), ('min', 1)])
# len:long - AutoOrderedDict([('total', 0), ('average', 0.0), ('max', 0), ('min', 9223372036854775807), ('won', AutoOrderedDict([('total', 0), ('average', 0.0), ('max', 0), ('min', 9223372036854775807)])), ('lost', AutoOrderedDict([('total', 0), ('average', 0.0), ('max', 0), ('min', 9223372036854775807)]))])
# len:short - AutoOrderedDict([('total', 1590), ('average', 7.7560975609756095), ('max', 53), ('min', 1), ('won', AutoOrderedDict([('total', 604), ('average', 26.26086956521739), ('max', 53), ('min', 12)])), ('lost', AutoOrderedDict([('total', 986), ('average', 5.417582417582418), ('max', 31), ('min', 1)]))])

# %%
print("Total Trades:",trades['total']['total'],"| Still Opened Trades:",trades['total']['open'],"| Closed Trades:",trades['total']['closed'])
print("Streak Won - Current", trades['streak']['won']['current'], "| Streak Won - Longest", trades['streak']['won']['longest'])
print("Streak Lost Current", trades['streak']['lost']['current'], "| Streak Won Longest", trades['streak']['lost']['longest'])
print("Pnl Gross Total:", trades['pnl']['gross']['total'],"| Pnl Gross Avg:",trades['pnl']['gross']['average'])
print("Pnl Net Total:", trades['pnl']['net']['total'],"| Pnl Net Avg:",trades['pnl']['net']['average'])
# Out:
# Total Trades: 206 | Still Opened Trades: 1 | Closed Trades: 205
# Streak Won - Current 0 | Streak Won - Longest 3
# Streak Lost Current 1 | Streak Won Longest 11
# Pnl Gross Total: -7.0 | Pnl Gross Avg: -0.03414634146341464
# Pnl Net Total: -7.0 | Pnl Net Avg: -0.03414634146341464

# %% [markdown]
# After executing the Bias Strategy, the ending portfolio value gathers to 999,224.44, leading to a net profit of 79.29 (approximately).
# There are 206 trades totally during the backtesting period.
# Among these 206 trades, 205 trades are closed, and 1 remains open at the end of the backtesting period.
# In addition, it's essentially imperative to consider that performance may vary with different datasets or historical data periods, rather than assumed to be consistent in every scenario. In addition, more further analysis or optimization may be required in order to improve the performance, if necessary.
